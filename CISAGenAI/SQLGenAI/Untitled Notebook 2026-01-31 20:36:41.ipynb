# %%
# %sql
SELECT * FROM dbdemos_summit_2024_class_01.raw.employees LIMIT 2

# %% [markdown]
# ai_classify

# %%
# %sql
SELECT ai_classify("My password is leaked.", ARRAY("urgent", "not urgent"));

# %%
# %sql
SELECT status,ai_classify(status, ARRAY("Yes", "No")) FROM dbdemos_summit_2024_class_01.raw.employees

# %% [markdown]
# ai_analyze_sentiment

# %%
# %sql
SELECT ai_analyze_sentiment('I am happy')

# %%
# %sql
SELECT status,ai_analyze_sentiment(status)FROM dbdemos_summit_2024_class_01.raw.employees

# %% [markdown]
# ai_extract

# %%
# %sql
SELECT ai_extract(
    'John Doe lives in New York and works for Acme Corp.',
    array('person', 'location', 'organization')
  )

# %%
# %sql
SELECT hire_date, ai_extract(hire_date,array("21-JUN-07")),ai_extract(hire_date,array("JUN-07")) FROM dbdemos_summit_2024_class_01.raw.employees

# %% [markdown]
# ai_fix_grammar

# %%
# %sql
SELECT ai_fix_grammar('She dont know what to did.');
